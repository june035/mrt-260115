# %% [markdown]
# *오늘의 미션!!! :D
# https://books.toscrape.com/ -> 메인 페이지에서 “책 제목+가격” 20개 가져오기
#
# -> 가산점 : 재고여부
# -> 책을 클릭했을 때, 이동할 수 있는 URL
# -> URL 이동 후 product description

# %%
import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

items = soup.select("article.product_pod")
for index, item in enumerate(items) : 
    title = item.select_one("h3").get_text(" ", strip=True)
    price = item.select_one("p.price_color").get_text(" ", strip=True).replace("Â", "")
    print(index + 1, f"제목: {title} / 가격: {price}")
# Out:
# 1 제목: A Light in the ... / 가격: £51.77
# 2 제목: Tipping the Velvet / 가격: £53.74
# 3 제목: Soumission / 가격: £50.10
# 4 제목: Sharp Objects / 가격: £47.82
# 5 제목: Sapiens: A Brief History ... / 가격: £54.23
# 6 제목: The Requiem Red / 가격: £22.65
# 7 제목: The Dirty Little Secrets ... / 가격: £33.34
# 8 제목: The Coming Woman: A ... / 가격: £17.93
# 9 제목: The Boys in the ... / 가격: £22.60
# 10 제목: The Black Maria / 가격: £52.15
# 11 제목: Starving Hearts (Triangular Trade ... / 가격: £13.99
# 12 제목: Shakespeare's Sonnets / 가격: £20.66
# 13 제목: Set Me Free / 가격: £17.46
# 14 제목: Scott Pilgrim's Precious Little ... / 가격: £52.29
# 15 제목: Rip it Up and ... / 가격: £35.02
# 16 제목: Our Band Could Be ... / 가격: £57.25
# 17 제목: Olio / 가격: £23.88
# 18 제목: Mesaerion: The Best Science ... / 가격: £37.59
# 19 제목: Libertarianism for Beginners / 가격: £51.33
# 20 제목: It's Only the Himalayas / 가격: £45.17

# %%
# 1번 제출 완료

import requests
from bs4 import BeautifulSoup

url = "https://books.toscrape.com/"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

items = soup.select("li.col-xs-6.col-sm-4.col-md-3.col-lg-3")
for index, item in enumerate(items) :
    title = item.select_one("h3").get_text(" ", strip=True),
    price = item.select_one("p.price_color").get_text(" ", strip=True).replace("Â", "")
    print(index + 1, f"제목: {title} / 가격: {price}")
# Out:
# 1 제목: ('A Light in the ...',) / 가격: £51.77
# 2 제목: ('Tipping the Velvet',) / 가격: £53.74
# 3 제목: ('Soumission',) / 가격: £50.10
# 4 제목: ('Sharp Objects',) / 가격: £47.82
# 5 제목: ('Sapiens: A Brief History ...',) / 가격: £54.23
# 6 제목: ('The Requiem Red',) / 가격: £22.65
# 7 제목: ('The Dirty Little Secrets ...',) / 가격: £33.34
# 8 제목: ('The Coming Woman: A ...',) / 가격: £17.93
# 9 제목: ('The Boys in the ...',) / 가격: £22.60
# 10 제목: ('The Black Maria',) / 가격: £52.15
# 11 제목: ('Starving Hearts (Triangular Trade ...',) / 가격: £13.99
# 12 제목: ("Shakespeare's Sonnets",) / 가격: £20.66
# 13 제목: ('Set Me Free',) / 가격: £17.46
# 14 제목: ("Scott Pilgrim's Precious Little ...",) / 가격: £52.29
# 15 제목: ('Rip it Up and ...',) / 가격: £35.02
# 16 제목: ('Our Band Could Be ...',) / 가격: £57.25
# 17 제목: ('Olio',) / 가격: £23.88
# 18 제목: ('Mesaerion: The Best Science ...',) / 가격: £37.59
# 19 제목: ('Libertarianism for Beginners',) / 가격: £51.33
# 20 제목: ("It's Only the Himalayas",) / 가격: £45.17
