# %%
age = int(input("당신의 나이는?"))

if age >= 19 :
    print("당신은 성인입니다")
# Out:
# 당신의 나이는? 20
# 당신은 성인입니다

# %%
age1 = int(input("흥민이의 나이는?"))
age2 = int(input("강인이의 나이는?"))

if age1 >= 19 and age2 >=19 :
    print("두 사람 모두 성인입니다")
# Out:
# 흥민이의 나이는? 24
# 강인이의 나이는? 19
# 두 사람 모두 성인입니다

# %%
age = int(input("당신의 나이는?"))

if age >= 19 :
    print("성인입니다")
else :
    print("미성년입니다")
# Out:
# 당신의 나이는? 8
# 미성년입니다

# %%
age = int(input("당신의 나이는?"))

if age >=19 :
    print("성인입니다")
elif age < 19 and age >= 13 :
    print("청소년입니다")
elif age < 13 and age >=5 :
    print("유소년입니다")
else :
    print("유아동입니다")
# Out:
# 당신의 나이는? 2
# 유아동입니다

# %%
money = int(input("얼마가 있습니까?"))

if money >= 100000 :
    print("뷔페")
else :
    if money > 50000 :
        print("한식당")
    else :
        print("집")
# Out:
# 얼마가 있습니까? 50000
# 집

# %%
money = int(input("얼마가 있습니까?"))

if money >= 100000 :
    print("뷔페")
elif money > 50000 :
        print("한식당")
else :
        print("집")
# Out:
# 얼마가 있습니까? 51000
# 한식당

# %%
digit = int(input("숫자를 입력하세요"))

if digit % 2 == 1 :
    print("홀수입니다")
else :
    print("짝수입니다")
# Out:
# 숫자를 입력하세요 10
# 짝수입니다

# %%
num1 = int(input("숫자를 입력하세요"))
num2 = int(input("숫자를 입력하세요"))
num3 = int(input("숫자를 입력하세요"))

if num1 <= num2 and num1 <= num3 :
    print(num1)
if num2 <= num1 and num2 <= num3 :
    print(num2)
if num3 <= num1 and num3 <= num2 :
    print(num3)
# Out:
# 숫자를 입력하세요 50
# 숫자를 입력하세요 2
# 숫자를 입력하세요 6
# 2

# %%
numbers = []

for i in range(3) :
    result = int(input(f"{i + 1}번째 숫자 : "))
    numbers.append(result)

num1, num2, num3 = numbers

if num1 <= num2 and num1 <= num3 :
    print(num1)
elif num2 <= num1 and num2 <= num3 :
    print(num2)
elif num3 <= num1 and num3 <= num2 :
    print(num3)
# Out:
# 1번째 숫자 :  50
# 2번째 숫자 :  4
# 3번째 숫자 :  6
# 4

# %%
numbers = []

for number in range(3) :
    result = int(input(f"{number+1}번째 숫자"))
    numbers.append(result)

num1, num2, num3 = numbers
print(min(numbers))
print(max(numbers))
# Out:
# 1번째 숫자 8
# 2번째 숫자 5
# 3번째 숫자 10
# 5
# 10

# %%
numbers = [int(input(f"{i+1}번째 숫자 : ")) for i in range(3)]
print(min(numbers))
# Out:
# 1번째 숫자 :  7
# 2번째 숫자 :  5
# 3번째 숫자 :  9
# 5
