# %%
nums = [3, 4, 1, 5]
print(nums)
# Out:
# [3, 4, 1, 5]

# %%
nums.sort()
print(nums)
# Out:
# [1, 3, 4, 5]

# %%
nums.reverse()
print(nums)
# Out:
# [5, 4, 3, 1]

# %%
words = "python is easy"
result = words.split()
print(result)

for r in result :
    print(r)
# Out:
# ['python', 'is', 'easy']
# python
# is
# easy
